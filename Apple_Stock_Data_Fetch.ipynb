# %% [markdown]
# ### Fetching Data

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# Fetch all historical data from 2000 to now
data = yf.download("AAPL", start="2000-01-01", end="2025-12-25")
print(data.shape)
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# (6535, 5)
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2000-01-03  0.839281  0.843498  0.762429  0.786328  535796800
# 2000-01-04  0.768521  0.829440  0.758680  0.811633  512377600
# 2000-01-05  0.779767  0.828971  0.772270  0.777893  778321600
# 2000-01-06  0.712287  0.802260  0.712287  0.795700  767972800
# 2000-01-07  0.746027  0.757274  0.716037  0.723534  460734400

# %% [markdown]
# ### Clean Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6535 entries, 2000-01-03 to 2025-12-24
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   6535 non-null   float64
#  1   (High, AAPL)    6535 non-null   float64
#  2   (Low, AAPL)     6535 non-null   float64
#  3   (Open, AAPL)    6535 non-null   float64
#  4   (Volume, AAPL)  6535 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 306.3 KB

# %%
data.isnull().sum()
# Out:
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %% [markdown]
# ### Save Data as CSV

# %%
data.to_csv("Apple_stock_clean_data.csv", index=True)
